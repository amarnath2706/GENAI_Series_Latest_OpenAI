# %%
print('om nama shivaya')
# Out:
# om nama shivaya

# %%
import os
import openai
from dotenv import load_dotenv

# %%
# !pip show openai
# Out:
# Name: openai
# Version: 0.28.0
# Summary: Python client library for the OpenAI API
# Home-page: https://github.com/openai/openai-python
# Author: OpenAI
# Author-email: support@openai.com
# License:
# Location: d:\anaconda3\envs\openaidemo\lib\site-packages
# Requires: aiohttp, requests, tqdm
# Required-by:

# %%
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
openai.api_key = OPENAI_API_KEY

# %%
openai.Model.list()
# Out:
# <OpenAIObject list at 0x20a7c927e20> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "id": "tts-1",
#       "object": "model",
#       "created": 1681940951,
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "tts-1-1106",
#       "object": "model",
#       "created": 1699053241,
#       "owned_by": "system"
#     },
#     {
#       "id": "dall-e-2",
#       "object": "model",
#       "created": 1698798177,
#       "owned_by": "system"
#     },
#     {
#       "id": "whisper-1",
#       "object": "model",
#       "created": 1677532384,
#       "owned_by": "openai-internal"
#     },
#     {
#       "id": "gpt-3.5-turbo-instruct",
#       "object": "model",
#       "created": 1692901427,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo-0125",
#       "object": "model",
#       "created": 1706048358,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-3.5-turbo",
#       "object": "model",
# ...

# %%
openai.Model.list()['data']
# Out:
# [<Model model id=tts-1 at 0x20a7c9276a0> JSON: {
#    "id": "tts-1",
#    "object": "model",
#    "created": 1681940951,
#    "owned_by": "openai-internal"
#  },
#  <Model model id=tts-1-1106 at 0x20a0c4ae480> JSON: {
#    "id": "tts-1-1106",
#    "object": "model",
#    "created": 1699053241,
#    "owned_by": "system"
#  },
#  <Model model id=dall-e-2 at 0x20a0c4ae340> JSON: {
#    "id": "dall-e-2",
#    "object": "model",
#    "created": 1698798177,
#    "owned_by": "system"
#  },
#  <Model model id=whisper-1 at 0x20a0c4f8f90> JSON: {
#    "id": "whisper-1",
#    "object": "model",
#    "created": 1677532384,
#    "owned_by": "openai-internal"
#  },
#  <Model model id=gpt-3.5-turbo-instruct at 0x20a0c4faed0> JSON: {
#    "id": "gpt-3.5-turbo-instruct",
#    "object": "model",
#    "created": 1692901427,
#    "owned_by": "system"
#  },
#  <Model model id=gpt-3.5-turbo-0125 at 0x20a0c4fb060> JSON: {
#    "id": "gpt-3.5-turbo-0125",
#    "object": "model",
#    "created": 1706048358,
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(openai.Model.list()['data'])
# Out:
#                              id object     created         owned_by
# 0                         tts-1  model  1681940951  openai-internal
# 1                    tts-1-1106  model  1699053241           system
# 2                      dall-e-2  model  1698798177           system
# 3                     whisper-1  model  1677532384  openai-internal
# 4        gpt-3.5-turbo-instruct  model  1692901427           system
# 5            gpt-3.5-turbo-0125  model  1706048358           system
# 6                 gpt-3.5-turbo  model  1677610602           openai
# 7                   babbage-002  model  1692634615           system
# 8                   davinci-002  model  1692634301           system
# 9                      dall-e-3  model  1698785189           system
# 10                  gpt-4o-mini  model  1721172741           system
# 11       gpt-4o-mini-2024-07-18  model  1721172717           system
# 12                     tts-1-hd  model  1699046015           system
# ...

# %%
#Chat Completion API and Completion API


#Chat completion API - GPT 3.5 Turbo 
#With the help of chat completion API we can pass multiple prompt

#Completion API - GPT Base

# %%
#Chat Completion API 

prompt = "Hello, How are you?"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role":"system","context":"You are a helpful assistant."}, #System prompt
        {"role":"user","content":""} #user prompt
    ]
)

print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[12], line 5
#       1 #Chat Completion API
#       3 prompt = "Hello, How are you?"
# ----> 5 response = openai.ChatCompletion.create(
#       6     model = "gpt-3.5-turbo",
#       7     messages = [
#       8         {"role":"system","context":"You are a helpful assistant."}, #System prompt
#       9         {"role":"user","content":""} #user prompt
#      10     ]
#      11 )
#      13 print(response)
#
# File d:\Anaconda3\envs\openaidemo\lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# ...

# %%
prompt = "Hello, How are you?"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role":"system","context":"You are a helpful assistant."}, #System prompt
        {"role":"user","content":""} #user prompt
    ]
)

print(response['choices'][0]['message']['content'])

# %%
#Chat Completion API Example
prompt1 = "Hello How Are You?"
prompt2 = "Iam 30 yrs old and I love to travel a lot"
prompt3 = "Tell me about me?"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role":"system","context":"You are a helpful assistant."}, #System prompt
        {"role":"user","content":prompt1}, #user prompt
        {"role":"user","content":prompt2},
        {"role":"user","content":prompt3},
    ]
)

print(response['choices'][0]['message']['content'])

# %%
#Chat Completion API Parameters
#1.Max tokens
prompt = "Tell me about Ratan Tata"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role":"system","context":"You are a helpful assistant."}, #System prompt
        {"role":"user","content":prompt} #user prompt
    ],
    max_tokens = 25 #It gives you the maximum of 25 tokens 
)

print(response['choices'][0]['message']['content'])

# %%
#2.Temperature
prompt = "Tell me about Ratan Tata"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role":"system","context":"You are a helpful assistant."}, #System prompt
        {"role":"user","content":prompt} #user prompt
    ],
    temperature = 0.6 #It gives you the randomness of the response or how much randomness we need?
    #close to 0 - Be stick to the promopt that we are giving
    #close to 1 - it will take some risk and generate random output
)
print(response['choices'][0]['message']['content'])

# %%
#3.n-parameter - how many responses we will get from the model
prompt = "Tell me about Ratan Tata"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role":"system","context":"You are a helpful assistant."}, #System prompt
        {"role":"user","content":""} #user prompt
    ],
    temperature = 0.6 #It gives you the randomness of the response or how much randomness we need?
    n=2 #gives you two responses
)
print(response['choices'][0]['message']['content'])

# %%
#Chat Completion API
prompt = "Give me the statement of this sentence : This movie is mindblowing!"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role":"system","context":"You are a helpful assistant."}, #System prompt
        {"role":"user","content":prompt} #user prompt
    ],
    temperature = 0.6 #It gives you the randomness of the response or how much randomness we need?
    #n=2 #gives you two responses
)
print(response['choices'][0]['message']['content'])

#We know that this sentiment would be positive

# %%
#Translation
prompt = "Give me the hindi translation of this sentence : This movie is mindblowing!"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role":"system","context":"You are a helpful assistant."}, #System prompt
        {"role":"user","content":prompt} #user prompt
    ],
    temperature = 0.6 #It gives you the randomness of the response or how much randomness we need?
    #n=2 #gives you two responses
)
print(response['choices'][0]['message']['content'])

# %%
#Generate code
prompt = "Give me the python code to add two numbers"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role":"system","context":"You are a helpful assistant."}, #System prompt
        {"role":"user","content":prompt} #user prompt
    ],
    temperature = 0.6 #It gives you the randomness of the response or how much randomness we need?
    #n=2 #gives you two responses
)
print(response['choices'][0]['message']['content'])
